# %%
import re
from utils.utils import *

import pandas as pd

# %%
server = 'biorxiv'
date_start = '2021-06-01'
date_end = '2021-06-01'
data_biorxiv = date_rxiv(server, date_start, date_end)
data_biorxiv.drop_duplicates(subset = ['doi'], keep = 'last', inplace = True)
data_biorxiv
# Out:
#                            doi  \
# 0               10.1101/501627
# 1               10.1101/711598
# 2    10.1101/2020.02.20.957142
# 3    10.1101/2020.04.20.050351
# 4    10.1101/2020.05.02.074237
# ..                         ...
# 146  10.1101/2021.06.01.446533
# 147  10.1101/2021.06.01.446545
# 148  10.1101/2021.06.01.446530
# 149  10.1101/2021.06.01.446439
# 150  10.1101/2021.06.01.446543
#
#                                                  title  \
# 0    Sensory coding and causal impact of mouse cort...
# 1    Implicit visuomotor adaptation remains limited...
# 2    Hierarchical dinucleotide distribution in geno...
# 3    Multiple paths to cold tolerance: the role of ...
# 4    Infanticide by females is a leading source of ...
# ..                                                 ...
# 146  Transcriptome analysis of developmental stages...
# 147  Evidence of MHC class I and II influencing vir...
# 148  A functionally divergent intrinsically disorde...
# ...

# %%
doi_article = data_biorxiv.at[0, 'doi']
server = 'biorxiv'
data_doi = article_detail(server, doi_article)
data_doi
# Out:
#               doi                                              title  \
# 0  10.1101/501627  Distinct contributions of mouse cortical areas...
# 1  10.1101/501627  Distinct contributions of mouse cortical areas...
# 2  10.1101/501627  A perceptual decision requires sensory but not...
# 3  10.1101/501627  A perceptual decision requires sensory but not...
# 4  10.1101/501627  A perceptual decision requires sensory but not...
# 5  10.1101/501627  Sensory coding and causal impact of mouse cort...
# 6  10.1101/501627  Sensory coding and causal impact of mouse cort...
#
#                                              authors author_corresponding  \
# 0  Zatka-Haas, P.; Steinmetz, N. A.; Carandini, M...     Kenneth D Harris
# 1  Zatka-Haas, P.; Steinmetz, N. A.; Carandini, M...     Kenneth D Harris
# 2  Zatka-Haas, P.; Steinmetz, N. A.; Carandini, M...     Kenneth D Harris
# 3  Zatka-Haas, P.; Steinmetz, N. A.; Carandini, M...     Kenneth D Harris
# ...

# %%
server = 'medrxiv'
data_medrxiv = date_rxiv(server, date_start, date_end)
data_medrxiv.drop_duplicates(subset = ['doi'], keep = 'last', inplace = True)
data_medrxiv
# Out:
#                             doi  \
# 0   10.1101/2020.08.19.20178343
# 1   10.1101/2020.09.02.20186999
# 2   10.1101/2020.12.23.20248757
# 3   10.1101/2021.01.13.21249598
# 4   10.1101/2021.02.03.21251007
# ..                          ...
# 68  10.1101/2021.05.30.21258040
# 69  10.1101/2021.05.31.21257562
# 70  10.1101/2021.05.31.21258118
# 71  10.1101/2021.05.31.21258122
# 72  10.1101/2021.05.31.21258110
#
#                                                 title  \
# 0   The Effects of Coronavirus Victimization Distr...
# 1   Temporal stability of the ventral attention ne...
# 2   The spatial spread of HIV in Malawi: An indivi...
# 3   Implementing Essential Coaching for Every Moth...
# 4   Intention to receive a COVID-19 vaccine: Resul...
# ..                                                ...
# 68  Effect of 2021 Assembly Election in India on C...
# 69  How is the distribution of psychological distr...
# 70  Epidemiological profile study of COVID-19 in W...
# ...

# %%
date_start = '2021-06-01'
date_end = '2021-06-01'
data_pub_biorxiv = date_published_article(date_start, date_end)
data_pub_biorxiv
# Out:
#                   biorxiv_doi                     published_doi  \
# 0   10.1101/2020.09.19.304584     10.4208/csiam-am.so-2020-0001
# 1   10.1101/2020.08.12.248948        10.1007/s10530-021-02576-7
# 2   10.1101/2020.09.13.291898  10.1016/j.neuroimage.2021.118204
# 3   10.1101/2020.09.03.281659                10.1242/jcs.254011
# 4   10.1101/2020.10.02.322743      10.1016/j.crmeth.2021.100010
# ..                        ...                               ...
# 77  10.1101/2021.01.19.427273            10.1093/plcell/koab151
# 78  10.1101/2021.01.27.428380        10.1016/j.cell.2021.05.040
# 79  10.1101/2020.06.05.136119      10.1371/journal.pbio.3000797
# 80  10.1101/2020.06.25.172445      10.1371/journal.pcbi.1009014
# 81  10.1101/2020.11.30.404905        10.1016/j.isci.2021.102681
#
#                                        preprint_title      preprint_category  \
# 0   On the Mathematics of RNA Velocity I: Theoreti...         bioinformatics
# ...

# %%
publisher_id = '10.15252'
date_start = '2020-06-01'
date_end = '2021-06-01'
data_pub_biorxiv = date_publisher_detail(publisher_id, date_start, date_end)
data_pub_biorxiv
# Out:
#                    biorxiv_doi             published_doi  \
# 0    10.1101/2020.01.02.893370  10.15252/embj.2020104389
# 1               10.1101/741314     10.15252/msb.20199419
# 2    10.1101/2020.02.26.965889     10.15252/msb.20209475
# 3               10.1101/836015   10.15252/emmm.201911861
# 4    10.1101/2020.02.03.931576   10.15252/embr.202050133
# ..                         ...                       ...
# 179  10.1101/2020.08.18.255455   10.15252/embr.202051530
# 180  10.1101/2020.09.18.304147    10.15252/msb.202010108
# 181  10.1101/2021.01.27.428391    10.15252/msb.202110267
# 182  10.1101/2020.11.24.395855    10.15252/msb.202010138
# 183  10.1101/2020.05.18.102178     10.15252/msb.20209813
#
#                                         preprint_title      preprint_category  \
# 0    A general role of zinc binding domain revealed...      molecular biology
# 1    Co-catabolism of arginine and succinate drives...          plant biology
# ...

# %%
data_stats = biorxiv_stats()
data_stats
# Out:
#       month new_papers new_papers_cumulative revised_papers  \
# 0   2013-11         60                    60             13
# 1   2013-12         49                   109             21
# 2   2014-01         54                   163             20
# 3   2014-02         66                   229             21
# 4   2014-03         43                   272             30
# ..      ...        ...                   ...            ...
# 87  2021-02       3155                113677           1230
# 88  2021-03       3524                117201           1431
# 89  2021-04       3250                120451           1262
# 90  2021-05       3229                123680           1272
# 91  2021-06       3000                126680           1192
#
#    revised_papers_cumulative
# 0                         13
# 1                         34
# 2                         54
# 3                         75
# 4                        105
# ..                       ...
# 87                     42993
# ...

# %%
data_biorxiv.to_csv('processed/biorxiv_june.csv', index=False)
data_medrxiv.to_csv('processed/medrxiv_june.csv', index=False)

# %%
print(data_biorxiv.at[5, 'abstract'])
# Out:
# MotivationPrediction of drug resistance and identification of its mechanisms in bacteria such as Mycobacterium tuberculosis, the etiological agent of tuberculosis, is a challenging problem. Solving this problem requires a transparent, accurate, and flexible predictive model. The methods currently used for this purpose rarely satisfy all of these criteria. On the one hand, approaches based on testing strains against a catalogue of previously identified mutations often yield poor predictive performance; on the other hand, machine learning techniques typically have higher predictive accuracy, but often lack interpretability and may learn patterns that produce accurate predictions for the wrong reasons. Current interpretable methods may either exhibit a lower accuracy or lack the flexibility needed to generalize them to previously unseen data.
#
# ...

# %%
first_words = set()
for i, abstract in enumerate(data_biorxiv['abstract'].tolist()):
    hits = []
    sentences = re.split('\n', abstract)
    for sent in sentences:
        try:
            first = sent.split()[0]
        except:
            first = ''
        hits.append(re.findall(r'\w*[A-Z]\w*[A-Z]\w*', first))
    #if hit:
    if sum([len(elem) for elem in hits]) > 0:
        for elem in hits:
            if len(elem) > 0:
                first_words.add(elem[0])
print(first_words)
# Out:
# {'ResultsThe', 'IntroductionIn', 'ResultsT4', 'HighlightsO_LI125', 'AO_SCPLOWBSTRACTC_SCPLOWMicrobial', 'HighlightsO_LIIn', 'ResultsViruxal', 'ConclusionsOur', 'AO_SCPLOWUTHORC_SCPLOW', 'O_FIG', 'ATP13A2', 'IO_SCPLOWMPORTANCEC_SCPLOWSaccharibacteria', 'HighlightsTrends', 'C_LIO_LICombination', 'C_LIO_LIPrior', 'ConclusionsViruxal', 'MethodsWe', 'HighlightsO_LISARS', 'ResultsIn', 'DTLVardef', 'MotivationIn', 'SUMMARYDrosophila', 'C_LIO_LIClosely', 'FindingThe', 'AO_SCPLOWBSTRACTC_SCPLOWThe', 'ResultsMacro', 'AO_SCPLOWBSTRACTC_SCPLOWRegression', 'C_LIO_LICOVID', 'BackgroundCherries', 'AO_SCPLOWBSTRACTC_SCPLOWSaccharibacteria', 'BackgroundNonhost', 'ResultsWe', 'AvailabilityCICLOP', 'CHARGE', 'BackgroundThe', 'BackgroundAcetone', 'C_LIO_LIIdentification', 'BackgroundBacterial', 'SIGNIFICANCE', 'MotivationPrediction', 'ConclusionThis', 'C_LIO_LISARS', 'RNA', 'C_LIO_LIGut', 'AbstractsUncontrolled', 'IMPORTANCEInfection', 'BackgroundIt', 'C_LIO_LICrAss', 'O_SCPLOWLC_SCPLOW', 'BackgroundTra
# ...

# %%
term_list = ['Results', 'Contribution', 'Highlights', 'Background', 'Conclusions', 'Introduction', 'Motivation', 'Methods', 'Teaser', \
             'Abstracts', 'Conclusion', 'IMPORTANCE', 'SUMMARY', 'Finding', 'Availability']
for word in first_words:
    present = 0
    for term in term_list:
        if term in word:
            present = 1
            break
    if present == 0:
        print(word)
###FIND GRAPHICAL ABSTRACT AND REMOVE!
###AUTHOR STATEMENT, IMPACT STATEMENT, SIGNIFICANCE STATEMENT, DATA STATEMENT
# Out:
# AO_SCPLOWBSTRACTC_SCPLOWMicrobial
# AO_SCPLOWUTHORC_SCPLOW
# O_FIG
# ATP13A2
# IO_SCPLOWMPORTANCEC_SCPLOWSaccharibacteria
# C_LIO_LICombination
# C_LIO_LIPrior
# DTLVardef
# C_LIO_LIClosely
# AO_SCPLOWBSTRACTC_SCPLOWThe
# AO_SCPLOWBSTRACTC_SCPLOWRegression
# C_LIO_LICOVID
# AO_SCPLOWBSTRACTC_SCPLOWSaccharibacteria
# CHARGE
# C_LIO_LIIdentification
# SIGNIFICANCE
# C_LIO_LISARS
# RNA
# C_LIO_LIGut
# C_LIO_LICrAss
# O_SCPLOWLC_SCPLOW
# C_LIO_LIORF3a
# AUTHOR
# GTPases
# C_LIO_LIPrevalence
# STATEMENT
# IMPACT
# eTOC
# C_LIO_LISingle
# C_LIO_LIA
# DATA
# C_LI
