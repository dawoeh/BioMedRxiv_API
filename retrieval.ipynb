# %%
import re
from utils.utils import *

import pandas as pd

# %%
server = 'biorxiv'
date_start = '2021-05-01'
date_end = '2021-06-30'
data_biorxiv = date_rxiv(server, date_start, date_end)
data_biorxiv.drop_duplicates(subset = ['doi'], keep = 'last', inplace = True)
data_biorxiv
# Out:
#                             doi  \
# 0                10.1101/035972
# 1                10.1101/067736
# 2                10.1101/165845
# 3                10.1101/181198
# 4                10.1101/196105
# ...                         ...
# 8677  10.1101/2021.06.30.450555
# 8678  10.1101/2021.06.30.450565
# 8679  10.1101/2021.06.30.450546
# 8680  10.1101/2021.06.30.450468
# 8681  10.1101/2021.06.30.450504
#
#                                                   title  \
# 0     Engineered acetoacetate-inducible whole-cell b...
# 1     Frameshift and wild-type proteins are highly s...
# 2     The effects of an 8-week mindful eating interv...
# 3     Plant genetic effects on microbial hubs impact...
# 4     Measuring nonapoptotic caspase activity with a...
# ...                                                 ...
# 8677  A Comprehensive Overview of the Physical Healt...
# 8678                        Evolution of a minimal cell
# 8679  Bayesian calibration, process modeling and unc...
# 8680  Rewiring the Three-Carbon Metabolism Abrogates...
# 8681  Proper migration of lymphatic endothelial cell...
#
#                                                 authors author_corresponding  \
# 0     Rutter, J. W.; Dekker, L.; Fedorec, A. J. H.; ...       Chris P Barnes
# 1     Wang, X.; Dong, Q.; Chen, G.; Zhang, J.; Liu, ...        Xiaolong Wang
# 2     Janssen, L. K.; Duif, I.; Speckens, A. E.; van...    Lieneke K Janssen
# 3     Brachi, B.; Filiault, D.; Whitehurst, H.; Darm...        Joy Bergelson
# 4     Nicholls, P.; Pack, T.; Urs, N.; Kumar, S.; Zh...       Peter Nicholls
# ...                                                 ...                  ...
# 8677  Palmer, C. E.; Sheth, C.; Marshall, A.; Adise,...        Chandni Sheth
# 8678  Lennon, J. T.; Moger-Reischer, R. Z.; Glass, J...         Jay T Lennon
# 8679  Helleckes, L. M.; Osthege, M.; Wiechert, W.; v...        Marco Oldiges
# 8680  Dube, A. K.; Malenfant, N.; Ladonne, F.; Piano...     Yves Bourbonnais
# 8681  Peng, D.; Ando, K.; Gloger, M.; Skoczylas, R.;...  Katarzyna Koltowska
#
#                        author_corresponding_institution        date version  \
# 0                             University College London  2021-05-21       3
# 1                             Ocean University of China  2021-05-03      10
# 2     Radboud University, Donders Institute for Brai...  2021-06-09       2
# 3     Department of Ecology and Evolution, Universit...  2021-05-11       3
# 4                                       Duke University  2021-05-20       4
# ...                                                 ...         ...     ...
# 8677                                 University of Utah  2021-06-30       1
# 8678                                 Indiana University  2021-06-30       1
# 8679                           Forschungszentrum Jülich  2021-06-30       1
# 8680                                   University Laval  2021-06-30       1
# 8681                                 Uppsala University  2021-06-30       1
#
#              type      license               category  \
# 0     new results        cc_no      synthetic biology
# 1     new results                            genetics
# 2     new results                        neuroscience
# 3     new results                       plant biology
# 4     new results                        neuroscience
# ...           ...          ...                    ...
# 8677  new results     cc_by_nd  developmental biology
# 8678  new results        cc_by   evolutionary biology
# 8679  new results        cc_by         bioengineering
# 8680  new results  cc_by_nc_nd           cell biology
# 8681  new results        cc_no  developmental biology
#
#                                                 jatsxml  \
# 0     https://www.biorxiv.org/content/early/2021/05/...
# 1     https://www.biorxiv.org/content/early/2021/05/...
# 2     https://www.biorxiv.org/content/early/2021/06/...
# 3     https://www.biorxiv.org/content/early/2021/05/...
# 4     https://www.biorxiv.org/content/early/2021/05/...
# ...                                                 ...
# 8677  https://www.biorxiv.org/content/early/2021/06/...
# 8678  https://www.biorxiv.org/content/early/2021/06/...
# 8679  https://www.biorxiv.org/content/early/2021/06/...
# 8680  https://www.biorxiv.org/content/early/2021/06/...
# 8681  https://www.biorxiv.org/content/early/2021/06/...
#
#                                                abstract published   server
# 0     Whole-cell biosensors hold potential in a vari...        NA  biorxiv
# 1     Frameshift protein sequences encoded by altern...        NA  biorxiv
# 2     Obesity is a highly prevalent disease, usually...        NA  biorxiv
# 3     Although complex interactions between hosts an...        NA  biorxiv
# 4     The protease caspase-3 is a key mediator of ap...        NA  biorxiv
# ...                                                 ...       ...      ...
# 8677  Physical health in childhood is crucial for ne...        NA  biorxiv
# 8678  Possessing only essential genes, a minimal cel...        NA  biorxiv
# 8679  AO_SCPLOWBSTRACTC_SCPLOWHigh-throughput experi...        NA  biorxiv
# 8680  Loss of membrane raft integrity, metabolic dys...        NA  biorxiv
# 8681  The migration of lymphatic endothelial cells (...        NA  biorxiv
#
# [7820 rows x 14 columns]

# %%
doi_article = data_biorxiv.at[0, 'doi']
server = 'biorxiv'
data_doi = article_detail(server, doi_article)
data_doi
# Out:
#               doi                                              title  \
# 0  10.1101/165845  The effect of an 8-week mindful eating interve...
# 1  10.1101/165845  The effects of an 8-week mindful eating interv...
#
#                                              authors author_corresponding  \
# 0  Janssen, L. K.; Duif, I.; Speckens, A. E.; van...    Lieneke K Janssen
# 1  Janssen, L. K.; Duif, I.; Speckens, A. E.; van...    Lieneke K Janssen
#
#                     author_corresponding_institution        date version  \
# 0  Radboud University, Donders Institute for Brai...  2017-07-21       1
# 1  Radboud University, Donders Institute for Brai...  2021-06-09       2
#
#           type license      category  \
# 0  new results   cc_no  neuroscience
# 1  new results          neuroscience
#
#                                              jatsxml  \
# 0  https://www.biorxiv.org/content/early/2017/07/...
# 1  https://www.biorxiv.org/content/early/2021/06/...
#
#                                             abstract published   server
# 0  Obesity is a highly prevalent disease, usually...        NA  biorxiv
# 1  Obesity is a highly prevalent disease, usually...        NA  biorxiv

# %%
server = 'medrxiv'
data_medrxiv = date_rxiv(server, date_start, date_end)
data_medrxiv.drop_duplicates(subset = ['doi'], keep = 'last', inplace = True)
data_medrxiv
# Out:
#                               doi  \
# 0     10.1101/2020.01.17.20017939
# 1     10.1101/2020.01.22.20018408
# 2     10.1101/2020.02.17.20021949
# 3     10.1101/2020.03.29.20046755
# 4     10.1101/2020.04.09.20058537
# ...                           ...
# 1265  10.1101/2021.06.25.21259564
# 1266  10.1101/2021.06.26.21259573
# 1267  10.1101/2021.06.26.21259584
# 1268  10.1101/2021.06.26.21259569
# 1269  10.1101/2021.06.29.21259504
#
#                                                   title  \
# 0     Assessing Knowledge, Attitudes, and Practices ...
# 1     miRNA biomarkers for diagnosis of ALS and FTD,...
# 2     Auditory tests for characterizing hearing defi...
# 3     Highly tweeted endodontic articles: a network ...
# 4     Observable Variations in Human Sex Ratio at Birth
# ...                                                 ...
# 1265  CYP2D6 Genotyping for Personalized Therapy of ...
# 1266  Microbiome profiles are associated with cognit...
# 1267  Assessing physical fitness during pregnancy: v...
# 1268  Discharge prediction of critical patients with...
# 1269  Relating in vitro neutralisation level and pro...
#
#                                                 authors  \
# 0     Barnard-Mayers, R. M.; Childs, E.; Corlin, L.;...
# 1     Magen, I.; Yacovzada, N.; Warren, J. D.; Helle...
# 2     Sanchez-Lopez, R.; Nielsen, S. G.; El-Haj-Ali,...
# 3               Kolahi, J.; Khazaei, S.; Iranmanesh, P.
# 4         Long, Y.; Chen, Q.; Larsson, H.; Rzhetsky, A.
# ...                                                 ...
# 1265  Maggadani, B. P.; Junusmin, K. I.; Sani, L. L....
# 1266  Streit, F.; Prandovszky, E.; Send, T.; Zillich...
# 1267  ROMERO-GALLARDO, L.; ROLDAN-REOYO, O.; CASTRO-...
# 1268  Fan, G.; Liu, H.; Yang, S.; Luo, L.; Wang, L.;...
# 1269  Cromer, D.; Reynaldi, A.; Steain, M.; Triccas,...
#
#        author_corresponding  \
# 0          Eleanor J Murray
# 1            Eran Hornstein
# 2        Raul Sanchez-Lopez
# 3              Jafar Kolahi
# 4           Andrey Rzhetsky
# ...                     ...
# 1265      Samuel J. Haryono
# 1266          Fabian Streit
# 1267  LIDIA ROMERO-GALLARDO
# 1268             Limin Rong
# 1269         David S Khoury
#
#                        author_corresponding_institution        date version  \
# 0                                     Boston University  2021-06-08       3
# 1                                    Weizmann Institute  2021-06-03       3
# 2     Hearing Systems Section, Department of Health ...  2021-06-12       3
# 3                                     Dental Hypotheses  2021-06-03       2
# 4                                 University of Chicago  2021-06-04       2
# ...                                                 ...         ...     ...
# 1265  Surgical Oncology Division, SJH Initiative, MR...  2021-06-30       1
# 1266  Department of Genetic Epidemiology in Psychiat...  2021-06-30       1
# 1267                              UNIVERSITY OF GRANADA  2021-06-30       1
# 1268  the Third Affiliated Hospital of Sun Yat-sen U...  2021-06-30       1
# 1269  Kirby Institute, University of New South Wales...  2021-06-30       1
#
#                      type      license                            category  \
# 0     PUBLISHAHEADOFPRINT        cc_by                        epidemiology
# 1     PUBLISHAHEADOFPRINT        cc_no                           neurology
# 2     PUBLISHAHEADOFPRINT  cc_by_nc_nd                      otolaryngology
# 3     PUBLISHAHEADOFPRINT  cc_by_nc_nd         dentistry and oral medicine
# 4     PUBLISHAHEADOFPRINT  cc_by_nc_nd      sexual and reproductive health
# ...                   ...          ...                                 ...
# 1265  PUBLISHAHEADOFPRINT        cc_by       pharmacology and therapeutics
# 1266  PUBLISHAHEADOFPRINT  cc_by_nc_nd  psychiatry and clinical psychology
# 1267  PUBLISHAHEADOFPRINT  cc_by_nc_nd                     sports medicine
# 1268  PUBLISHAHEADOFPRINT  cc_by_nc_nd                           neurology
# 1269  PUBLISHAHEADOFPRINT        cc_no                 infectious diseases
#
#                                                 jatsxml  \
# 0     https://www.medrxiv.org/content/early/2021/06/...
# 1     https://www.medrxiv.org/content/early/2021/06/...
# 2     https://www.medrxiv.org/content/early/2021/06/...
# 3     https://www.medrxiv.org/content/early/2021/06/...
# 4     https://www.medrxiv.org/content/early/2021/06/...
# ...                                                 ...
# 1265  https://www.medrxiv.org/content/early/2021/06/...
# 1266  https://www.medrxiv.org/content/early/2021/06/...
# 1267  https://www.medrxiv.org/content/early/2021/06/...
# 1268  https://www.medrxiv.org/content/early/2021/06/...
# 1269  https://www.medrxiv.org/content/early/2021/06/...
#
#                                                abstract published   server
# 0     BackgroundCausal graphs provide a key tool for...        NA  medrxiv
# 1     The neurodegenerative syndromes amyotrophic la...        NA  medrxiv
# 2     The Better hEAring Rehabilitation (BEAR) proje...        NA  medrxiv
# 3     IntroductionTo identify active journals, autho...        NA  medrxiv
# 4     The human sex ratio at birth (SRB), defined as...        NA  medrxiv
# ...                                                 ...       ...      ...
# 1265  Tamoxifen is a Selective Estrogen-Receptor Mod...        NA  medrxiv
# 1266  Prenatal, perinatal, and postnatal factors hav...        NA  medrxiv
# 1267  BackgroundPhysical fitness (PF) is a powerful ...        NA  medrxiv
# 1268  ObjectivesPrognostication of spinal cord injur...        NA  medrxiv
# 1269  A recent study analysed the relationship betwe...        NA  medrxiv
#
# [1197 rows x 14 columns]

# %%
date_start = '2021-06-01'
date_end = '2021-06-01'
data_pub_biorxiv = date_published_article(date_start, date_end)
data_pub_biorxiv
# Out:
#                   biorxiv_doi                     published_doi  \
# 0   10.1101/2020.09.19.304584     10.4208/csiam-am.so-2020-0001
# 1   10.1101/2020.08.12.248948        10.1007/s10530-021-02576-7
# 2   10.1101/2020.09.13.291898  10.1016/j.neuroimage.2021.118204
# 3   10.1101/2020.09.03.281659                10.1242/jcs.254011
# 4   10.1101/2020.10.02.322743      10.1016/j.crmeth.2021.100010
# ..                        ...                               ...
# 77  10.1101/2021.01.19.427273            10.1093/plcell/koab151
# 78  10.1101/2021.01.27.428380        10.1016/j.cell.2021.05.040
# 79  10.1101/2020.06.05.136119      10.1371/journal.pbio.3000797
# 80  10.1101/2020.06.25.172445      10.1371/journal.pcbi.1009014
# 81  10.1101/2020.11.30.404905        10.1016/j.isci.2021.102681
#
#                                        preprint_title      preprint_category  \
# 0   On the Mathematics of RNA Velocity I: Theoreti...         bioinformatics
# 1   Matching a snail's pace: Successful use of env...                ecology
# 2   Subject identification using edge-centric func...           neuroscience
# 3   Twinfilin1 controls lamellipodial protrusive a...           cell biology
# 4   Uncovering biomarkers during therapeutic neuro...           neuroscience
# ..                                                ...                    ...
# 77  VISUAL network analysis reveals the role of BE...  developmental biology
# 78  Low-Dose Ad26.COV2.S Protection Against SARS-C...             immunology
# 79  A unifying framework disentangles genetic, epi...        systems biology
# 80  Accessible, Reproducible, and Scalable Machine...         bioinformatics
# 81  Characterization of SARS-CoV-2 N protein revea...           biochemistry
#
#    preprint_date published_date published_citation_count
# 0     2020-09-20     2021-06-01               2021-06-01
# 1     2020-08-14     2021-06-01               2021-06-01
# 2     2020-09-14     2021-06-01               2021-06-01
# 3     2020-09-03     2021-06-01               2021-06-01
# 4     2020-10-09     2021-06-01               2021-06-01
# ..           ...            ...                      ...
# 77    2021-01-20     2021-06-01               2021-07-16
# 78    2021-01-27     2021-06-01               2021-07-16
# 79    2020-06-05     2021-06-01               2021-07-16
# 80    2020-06-28     2021-06-01               2021-07-16
# 81    2020-11-30     2021-06-01               2021-07-16
#
# [82 rows x 7 columns]

# %%
publisher_id = '10.15252'
date_start = '2020-06-01'
date_end = '2021-06-01'
data_pub_biorxiv = date_publisher_detail(publisher_id, date_start, date_end)
data_pub_biorxiv
# Out:
#                    biorxiv_doi             published_doi  \
# 0    10.1101/2020.01.02.893370  10.15252/embj.2020104389
# 1               10.1101/741314     10.15252/msb.20199419
# 2    10.1101/2020.02.26.965889     10.15252/msb.20209475
# 3               10.1101/836015   10.15252/emmm.201911861
# 4    10.1101/2020.02.03.931576   10.15252/embr.202050133
# ..                         ...                       ...
# 179  10.1101/2020.08.18.255455   10.15252/embr.202051530
# 180  10.1101/2020.09.18.304147    10.15252/msb.202010108
# 181  10.1101/2021.01.27.428391    10.15252/msb.202110267
# 182  10.1101/2020.11.24.395855    10.15252/msb.202010138
# 183  10.1101/2020.05.18.102178     10.15252/msb.20209813
#
#                                         preprint_title      preprint_category  \
# 0    A general role of zinc binding domain revealed...      molecular biology
# 1    Co-catabolism of arginine and succinate drives...          plant biology
# 2    CRISPR-TAPE: protein-centric CRISPR guide desi...         bioinformatics
# 3    Proteasome subunit PSMC3 variants cause neuros...               genetics
# 4    Differential functions of FANCI and FANCD2 ubi...           biochemistry
# ..                                                 ...                    ...
# 179  Characterization of histone inheritance patter...  developmental biology
# 180  JSTA: joint cell segmentation and cell type an...        systems biology
# 181  Behavioral fingerprints predict insecticide an...        systems biology
# 182  Diverse natural variants suppress mutations in...               genetics
# 183  Integrative proteomics reveals principles of d...        systems biology
#
#     preprint_date published_date published_citation_count
# 0      2020-01-03     2020-06-02               2020-06-02
# 1      2019-08-21     2020-06-03               2020-06-03
# 2      2020-02-26     2020-06-02               2020-06-02
# 3      2019-11-17     2020-06-05               2020-06-05
# 4      2020-02-03     2020-06-08               2020-06-08
# ..            ...            ...                      ...
# 179    2020-08-19     2021-05-25               2021-07-16
# 180    2020-09-20     2021-05-31               2021-07-16
# 181    2021-01-28     2021-05-25               2021-07-16
# 182    2020-11-24     2021-05-27               2021-07-16
# 183    2020-05-19     2020-12-01               2021-07-16
#
# [184 rows x 7 columns]

# %%
data_stats = biorxiv_stats()
data_stats
# Out:
#       month new_papers new_papers_cumulative revised_papers  \
# 0   2013-11         60                    60             13
# 1   2013-12         49                   109             21
# 2   2014-01         54                   163             20
# 3   2014-02         66                   229             21
# 4   2014-03         43                   272             30
# ..      ...        ...                   ...            ...
# 87  2021-02       3155                113677           1230
# 88  2021-03       3524                117201           1431
# 89  2021-04       3250                120451           1262
# 90  2021-05       3229                123680           1272
# 91  2021-06       3000                126680           1192
#
#    revised_papers_cumulative
# 0                         13
# 1                         34
# 2                         54
# 3                         75
# 4                        105
# ..                       ...
# 87                     42993
# 88                     44424
# 89                     45686
# 90                     46958
# 91                     48150
#
# [92 rows x 5 columns]

# %%
data_biorxiv.to_csv('processed/biorxiv_june.csv', index=False)
data_medrxiv.to_csv('processed/medrxiv_june.csv', index=False)

# %%
print(data_biorxiv.at[5, 'abstract'])
# Out:
# Accurate and timely functional genome annotation is essential for translating basic pathogen research into clinically impactful advances. Here, through literature curation and structure-function inference, we systematically update the functional genome annotation of Mycobacterium tuberculosis virulent type strain H37Rv. First, we systematically curated annotations for 589 genes from 662 publications, including 282 gene products absent from leading databases. Second, we modeled 1,711 under-annotated proteins and developed a semi-automated pipeline that captured shared function between 400 protein models and structural matches of known function on protein data bank, including drug efflux proteins, metabolic enzymes, and virulence factors. In aggregate, these structure- and literature-derived annotations update 940/1,725 under-annotated H37Rv genes and generate hundreds of functional hypotheses. Retrospectively applying the annotation to a recent whole-genome transposon mutant screen provided missing function for 48% (13/27) of under-annotated genes altering antibiotic efficacy and 33% (23/69) required for persistence during mouse TB infection. Prospective application of the protein models enabled us to functionally interpret novel laboratory generated Pyrazinamide-resistant (PZA) mutants of unknown function, which implicated the emerging Coenzyme A depletion model of PZA action in the mutants PZA resistance. Our findings demonstrate the functional insight gained by integrating structural modeling and systematic literature curation, even for widely studied microorganisms. Functional annotations and protein structure models are available at https://tuberculosis.sdsu.edu/H37Rv in human- and machine-readable formats.
#
# IMPORTANCEMycobacterium tuberculosis, the primary causative agent of tuberculosis, kills more humans than any other infectious bacteria. Yet 40% of its genome is functionally uncharacterized, leaving much about the genetic basis of its resistance to antibiotics, capacity to withstand host immunity, and basic metabolism yet undiscovered. Irregular literature curation for functional annotation contributes to this gap. We systematically curated functions from literature and structural similarity for over half of poorly characterized genes, expanding the functionally annotated Mycobacterium tuberculosis proteome. Applying this updated annotation to recent in vivo functional screens added functional information to dozens of clinically pertinent proteins described as having unknown function. Integrating the annotations with a prospective functional screen identified new mutants resistant to a first-line TB drug supporting an emerging hypothesis for its mode of action. These improvements in functional interpretation of clinically informative studies underscores the translational value of this functional knowledge. Structure-derived annotations identify hundreds of high-confidence candidates for mechanisms of antibiotic resistance, virulence factors, and basic metabolism; other functions key in clinical and basic tuberculosis research. More broadly, it provides a systematic framework for improving prokaryotic reference annotations.

# %%
first_words = set()
for i, abstract in enumerate(data_biorxiv['abstract'].tolist()):
    hits = []
    sentences = re.split('\n', abstract)
    for sent in sentences:
        try:
            first = sent.split()[0]
        except:
            first = ''
        hits.append(re.findall(r'\w*[A-Z]\w*[A-Z]\w*', first))
    #if hit:
    if sum([len(elem) for elem in hits]) > 0:
        for elem in hits:
            if len(elem) > 0:
                first_words.add(elem[0])
print(first_words)
# Out:
# {'ConclusionsAn', 'BackgroundNeuroplastic', 'RELN', 'ResultsFemale', 'C_LIO_LIBoth', 'ResultsHierarchical', 'BackgroundAbrupt', 'BackgroundDeciphering', 'C_LIO_LIRecruitment', 'BackgroundGasdermin', 'PlaF', 'ConclusionsWNK463', 'SummaryiNKTs', 'C_LIO_LIAn', 'ResultsParticipants', 'ConclusionDespite', 'ResultsStaphylococcus', 'ConclusionsUsing', 'HIV', 'HighlightIn', 'AO_SCPLOWBSTRACTC_SCPLOWPhylogenetic', 'BackgroundCOVID', 'C_LIO_LIInter', 'O_FIG_DISPLAY_L', 'CONCLUSIONThese', 'C_LIO_LIPollen', 'C_LIO_LIEnteric', 'C_LIO_LIAM', 'HighlightsO_LIDifferential', 'ImportanceCell', 'MethodsArticles', 'IntroductionProstate', 'MethodsMeasuring', 'ImportanceViruses', 'SAIGE', 'CONCLUSIONSGenetic', 'MADS', 'C_LIO_LICompound', 'BackgroundVariation', 'LOTUS', 'C_FIG_DISPLAY', 'SARS', 'NMR', 'C_LIO_LIPropionigenium', 'ResultsSubject', 'HEK293', 'MethodologyWe', 'ResultsData', 'O_LISigmoid', 'MethodsRat', 'C_LIO_LIInterpretation', 'BackgroundSARS', 'Pitx2ASE', 'SIGNIFICANCEElectrotaxis', 'C_LIO_LIMorphometric', 'ABCB1', 'ConclusionAffinity', 'NEIL1', 'STATEMENT', 'BackgroundVascular', 'C_LIO_LISynthesis', 'C_LIO_LIConvenient', 'BackgroundPolymyxin', 'C_LIO_LIHFOs', 'HighlightsO_LIUltra', 'HighlightGlutathione', 'BackgroundOptically', 'ConclusionsDolosigranulum', 'INTRODUCTIONAggregation', 'C_LIO_LIAxon', 'ConclusionsIncreased', 'MotivationAccumulating', 'ResultsExposure', 'ConclusionsDue', 'FindingsHere', 'C_LIO_LIIntegration', 'HighlightsO_LICell', 'C_LIO_LIDefinition', 'NEW', 'MethodsLipophilic', 'SYNOPSIS', 'BackgroundCell', 'ConclusionsFindings', 'AO_SCPLOWBSTRACTC_SCPLOWNeuroimaging', 'BackgroundScab', 'ResultsAltogether', 'C_LIO_LIModerate', 'ImportanceClassical', 'ImportanceRhizosphere', 'ObjectiveThe', 'MethodsChronic', 'O_LITo', 'C_LIO_LIDeamidated', 'ResultsResults', 'MotivationSmoldyn', 'ResultsVideo', 'DatabaseenviLink', 'AvailabilityMMMVI', 'C_LIO_LIOral', 'MaterialsFrom', 'MicroRNA', 'BRIEF', 'POGZ', 'C_LIO_LIFate', 'ResultsSocial', 'IMPORTANCEAfter', 'PURPOSEMillions', 'AvailabilityNLoed', 'MethodsSamples', 'O_LIStudies', 'BackgroundMost', 'IMPORTANCEWe', 'C_LIO_LIUtilising', 'BackgroundExisting', 'AO_SCPLOWBSTRACTC_SCPLOWShared', 'ImportanceCholera', 'MVPAlab', 'IMPORTANCEBiodiesel', 'RESULTSDose', 'ConclusionsGraphOmics', 'ResultsViruxal', 'ConclusionsProbiotics', 'MotivationA', 'C_LIO_LISignificant', 'MotivationNon', 'RationaleThe', 'DECLARATIONSO_ST_ABSFundingC_ST_ABSThis', 'SummaryWhole', 'BackgroundCopy', 'ConclusionsDeepFlu', 'BackgroundConservation', 'BackgroundPlasmodium', 'C_LIO_LIBehavioral', 'InterpretationExtracellular', 'IntroductionRapid', 'HighlightsFlash', 'ResultsWS', 'LocationFrance', 'MotivationQuerying', 'HighlightsO_LIDNA', 'C_LIO_LIClassifying', 'IMPORTANCETo', 'AvailabilityMutaframe', 'MethodsCRISPR', 'AimIn', 'HighlightsO_LIGeneral', 'ConclusionSALARECON', 'MethodsFocusing', 'ResultsBLENDS', 'ImportanceHuman', 'ObjectivesIn', 'C_LIO_LIModel', 'SignificancePhenotypic', 'HighlightsO_LISystematic', 'SignificanceModifications', 'BackgroundEnhancers', 'SignificanceSugar', 'SignificanceAccurate', 'ResultsWe', 'ResultsAllelic', 'ConclusionTreating', 'RNF43', 'IntroductionTransparency', 'IMPORTANCERotavirus', 'O_LIHosts', 'ConclusionsDiet', 'C_LIO_LIBuilding', 'ResultIn', 'C_LIO_LIGIV', 'REV', 'IMPORTANCEMethanogens', 'MethodsAdult', 'MethodsVirus', 'PurposeDiffusion', 'METHODSThe', 'C_LIO_LIComparison', 'BackgroundSpatio', 'SignificanceEcological', 'C_LIO_LIEight', 'AvailabilitysynVep', 'SIGNIFICANCEThe', 'BackgroundAmylin', 'BackgroundBiological', 'HIGHLIGHTO_LIOvulatory', 'BackgroundThe', 'C_LIO_LIPrdm3', 'C_LIO_LIOverexpression', 'C_LIO_LIKcr', 'ImportanceVery', 'ResultsNormalizing', 'C_LIO_LIPhenomics', 'MethodsSARS', 'SO_SCPLOWUMMARYC_SCPLOWState', 'ResultsAdipose', 'ResultsHDnGAN', 'ContextFunctional', 'C_LIO_LIHAUSP', 'PurposeData', 'SHP2', 'SignificanceAntimicrobial', 'C_LIO_LITransferability', 'DesignUsing', 'ResultsCaD23', 'NickJD', 'EP300', 'ConclusionsViruxal', 'ImportanceMyxococcus', 'MethodsHuma ...

# %%
term_list = ['Results', 'Contribution', 'Highlights', 'Background', 'Conclusions', 'Introduction', 'Motivation', 'Methods', 'Teaser', \
             'Abstracts', 'Conclusion', 'IMPORTANCE', 'SUMMARY', 'Finding', 'Availability', 'Highlight', 'Importance', 'Summary', 'RESULTS', \
            'Rationale', 'Aim', 'Significance', 'Objectives', 'Purpose', 'Synopsis', 'METHODS', 'SIGNIFICANCE', 'Objectives', 'Design', \
            'Objective', 'Approach', 'Methodology', 'HIGHLIGHTS', 'INTRODUCTION', 'Abstract', 'CONCLUSIONS', 'Software', 'Interpretations', \
            'FUNDING', 'Summery', 'Perspective', 'Discussion', 'CONCLUSION', 'DISCUSSION', 'Funding', 'Advances', 'Classification', 'SYNOPSIS', \
            'BACKGROUND', 'Method', 'Innovation', 'PREMISE', 'Implications', 'STATEMENT', 'Contact', 'Location', 'Outlook', 'TEASER', \
             'Interpretation', 'eTOC', 'Result', 'TABLE', 'Taxon', 'Measurements', 'Participants', 'Sentence', 'Materials', \
             'PURPOSE', 'Context', 'Setting', 'SUMMMARY', 'Hypothesis', 'Keypoitns', 'Implementation', 'Limitations', 'OBJECTIVE', \
             'Precis', 'Questions', 'Database', \
             'C_LIO_LI', 'O_LI', 'O_FIG_DISPLAY_L', 'O_SCPLOWBSTRACTC_SCPLOW', 'AO_SCPLOWUTHORC_SCPLOW', 'SO_SCPLOWUMMARYC_SCPLOW', \
            'C_TABLECAPTION', 'IO_SCPLOWMPORTANCEC_SCPLOW', 'C_LI', 'C_FIG_DISPLAY', 'C_TEXTBOX', 'O_SCPLOWLC_SCPLOW', \
            'SO_SCPLOWIGNIFICANCEC_SCPLOWO_SCPCAP', 'KO_SCPLOWEYC_SCPLOWO_SCPCAP', 'C_QD']
for word in first_words:
    present = 0
    for term in term_list:
        if term in word:
            present = 1
            break
    if present == 0:
        print(word)
###FIND GRAPHICAL ABSTRACT AND REMOVE! Remove after ToC! Remove between O_FIG/O_TBL and C_FIG/C_TBL
###AUTHOR STATEMENT, IMPACT STATEMENT, SIGNIFICANCE STATEMENT, DATA STATEMENT, ARTICLE SUMMARY, CONFLICT OF INTEREST, IN BRIEF, METHODOLOGY/PRINCIPAL FINDINGS
##ABSTRACT AND KEYWORDS, PROGRAM SUMMARY, ARTICLE SUMMARY, NEW & NOTEWORTHY
# Out:
# RELN
# PlaF
# HIV
# SAIGE
# MADS
# LOTUS
# SARS
# NMR
# HEK293
# Pitx2ASE
# ABCB1
# NEIL1
# NEW
# MicroRNA
# BRIEF
# POGZ
# MVPAlab
# RNF43
# REV
# SHP2
# NickJD
# EP300
# SLC9A6
# H2S
# AAA
# RAGE
# HAT1
# AUTHOR
# ASE
# HOX
# CEP78
# SOCS3
# PIEZO
# RingkasanMemahami
# BICEPS
# RNases
# cAMP
# RAG1
# COBREXA
# CRISPRs
# AMPK
# GRINA
# CDK4
# EP400
# NON
# CcoA
# PIK3CA
# DLEU2
# CTCF
# ATRX
# PoxtA
# PIWI
# ZMIZ1
# GGCT
# CspA
# TMEM120A
# MutS
# eDNA
# GIGANTEA
# LI
# ONE
# LY
# VERNALIZATION
# CD33
# tRNAs
# DNA
# HVEM
# NGLY1
# Transition_Disorder_Prediction
# ARTICLE
# MRSE
# AGT
# EEG
# UniProt
# ATP13A2
# CCS
# LncRNA
# WHAT
# STUDY
# CD177
# GRAPHIC
# SETDB1
# CRISPR
# PKC
# SUMO
# ATP
# COPII
# fMRS
# eQTL
# KdpFABC
# GTPases
# DRD2
# TnCentral
# SARM1
# IL
# FTSJ1
# DeepMind
# HP1
# microRNAs
# GABAergic
# LncRNAs
# NOTCH1
# HSV
# MicroRNAs
# SignalP
# MCM
# KRAS
# EVs
# DWARF14
# IDH
# FOXO
# CDK9
# GABA
# PG9
# RAS
# PTEN
# KEY
# RAD51
# SNARE
# TYPE
# CNS
# TREM2
# CPC
# SwrA
# GRASP55
# SHAPE
# BMP
# FGF
# MT1
# ISG15
# VIR
# MDM
# IMPACT
# POU
# CFTR
# STRipy
# IN
# GUIdEStaR
# RNA
# FoF1
# CD8
# MSC
# MIC50
# CBMOS
# PACS
# ACM
# PI4KIII
# ToC
# TRIM25
# tRNAscan
# DsbA
# PspA
# TOC
# 1RNA
# mRNA
# NF
# AIM
# RNF213
# ER
# METHODOLOGY
# KMT2D
# PKA
# PavlopoulosLab
# TRAAK
# DTLVardef
# AMS
# CONFLICT
# RMRP
# ZNF462
# ATB0
# CHARGE
# GFI1
# DUX4
# CD4
# DATA
# ABSTRACT
# ABCA1
# CIViC
# EXPERIMENTAL
# hCDKL5
# GWAS
# PTPRT
# NmMetQ
# SCoPE2
# FIB
# FiberSim
# CHCHD10
# FTY720
# DatumKB
# TACSTD2
# DeepImageJ
# HKG
# CD24
# RNAs
# ORAI1
# CIC
# O_QD
# COVID
# GRAPHICAL
# HdeA
# MiRNA
# FAIRSCAPE
# USP5
# mTORC2
# GC
# TALPID3
# PROGRAM

# %%
abstract_list = data_biorxiv['abstract'].tolist()
print(abstract_list[4909])
# Out:
# The uses of bivalve molluscs in environmental biomonitoring have recently gained momentum due to their ability to indicate and concentrate human pathogenic microorganisms. In the context of the health crisis caused by the COVID-19 epidemic, the objective of this study was to determine if the SARS-CoV-2 ribonucleic acid genome can be detected in zebra mussels (Dreissena polymorpha) exposed to raw and treated urban wastewaters from two separate plants to support its interest as bioindicator of the SARS-CoV-2 genome contamination in water. The zebra mussels were exposed to treated wastewater through caging at the outlet of two plants located in France, as well as to raw wastewater at laboratory scale in controlled conditions. Within their digestive tissues, our results showed that SARS-CoV-2 genome was detected in zebra mussels, whether in raw and treated wastewaters. Moreover, the detection of the SARS-CoV-2 genome in such bivalve molluscans appeared even with low concentrations in raw wastewaters. This is the first detection of the SARS-CoV-2 genome in the tissues of a sentinel species exposed to raw and treated urban wastewaters. Despite the need for development for quantitative approaches, these results support the importance of such invertebrate organisms, especially zebra mussel, for the active surveillance of pathogenic microorganisms and their indicators in environmental waters.
#
# Graphical abstract
#
# O_FIG O_LINKSMALLFIG WIDTH=200 HEIGHT=71 SRC="FIGDIR/small/446136v1_ufig1.gif" ALT="Figure 1">
# View larger version (19K):
# org.highwire.dtl.DTLVardef@781087org.highwire.dtl.DTLVardef@853128org.highwire.dtl.DTLVardef@5e667forg.highwire.dtl.DTLVardef@19b243e_HPS_FORMAT_FIGEXP  M_FIG C_FIG

# %%
abstract_list = data_biorxiv['abstract'].tolist()

header_list = ['Results', 'Contribution', 'Highlights', 'Background', 'Conclusions', 'Introduction', 'Motivation', 'Methods', 'Teaser', \
             'Abstracts', 'Conclusion', 'IMPORTANCE', 'SUMMARY', 'Finding', 'Availability', 'Highlight', 'Importance', 'Summary', 'RESULTS', \
            'Rationale', 'Aim', 'Significance', 'Objectives', 'Purpose', 'Synopsis', 'METHODS', 'SIGNIFICANCE', 'Objectives', 'Design', \
            'Objective', 'Approach', 'Methodology', 'HIGHLIGHTS', 'INTRODUCTION', 'Abstract', 'CONCLUSIONS', 'Software', 'Interpretations', \
            'FUNDING', 'Summery', 'Perspective', 'Discussion', 'CONCLUSION', 'DISCUSSION', 'Funding', 'Advances', 'Classification', 'SYNOPSIS', \
            'BACKGROUND', 'Method', 'Innovation', 'PREMISE', 'Implications', 'STATEMENT', 'Contact', 'Location', 'Outlook', 'TEASER', \
             'Interpretation', 'eTOC', 'Result', 'TABLE', 'Taxon', 'Measurements', 'Participants', 'Sentence', 'Materials', \
             'PURPOSE', 'Context', 'Setting', 'SUMMMARY', 'Hypothesis', 'Keypoitns', 'Implementation', 'Limitations', 'OBJECTIVE', \
             'Precis', 'Questions', 'Database', 'Paragraph', 'PARAGRAPH']

markup_list =  ['C_LIO_LI', 'O_LI', 'O_SCPLOWBSTRACTC_SCPLOW', 'AO_SCPLOWUTHORC_SCPLOW', 'SO_SCPLOWUMMARYC_SCPLOW', 'SO_SCPLOWIGNIFICANCEC_SCPLOWO_SCPCAP', \
            'C_TABLECAPTION', 'IO_SCPLOWMPORTANCEC_SCPLOW', 'C_LI', 'C_TEXTBOX', 'O_SCPLOWLC_SCPLOW', 'C_SCPCAPO_SCPLOWPOINTSC_SCPLOW', \
            'SO_SCPLOWIGNIFICANCEC_SCPLOWO_SCPCAP', 'KO_SCPLOWEYC_SCPLOWO_SCPCAP', 'C_QD', 'C_ST_ABSO_LI', 'O_ST_ABS', 'C_ST_ABS', \
               'C_SCPCAPO_SCPLOWPOINTSC_SCPLOW', 'SO_SCPLOWIGNIFICANCEC_SCPLOWO_SCPCAP', 'C_SCPCAPO_SCPLOWC_SCPLOW', 'O_TEXTBOX', 'O_SCPCAP']

statement_list = ['AUTHOR STATEMENT', 'IMPACT STATEMENT', 'SIGNIFICANCE STATEMENT', 'DATA STATEMENT', 'ARTICLE SUMMARY', \
                  'CONFLICT OF INTEREST', 'IN BRIEF', 'METHODOLOGY/PRINCIPAL FINDINGS', 'ABSTRACT AND KEYWORDS', 'PROGRAM SUMMARY', \
                  'ARTICLE SUMMARY', 'NEW & NOTEWORTHY', 'Graphical abstract']


markup_list.sort(key = len, reverse=True)

for i, abstract in enumerate(abstract_list):
    for markup in markup_list:
        abstract = abstract.replace(markup, ' ')
    for statement in statement_list:
        abstract = abstract.replace(statement, ' ')
    words = re.findall(r'\S+|\n',abstract)
    pointer = 1
    stop = 0
    new_words=[]
    for k, word in enumerate(words):
        hit = []
        if pointer == 1:
            hit.append(re.findall(r'\w*[A-Z]\w*[A-Z]\w*', word))
            if len(hit) > 0:
                for header in header_list:
                    if header in word:
                        word = word.replace(header, '')               
        if 'O_FIG' in word:
            stop = 1
        if 'O_TBL' in word:
            stop = 1
        words[k] = word
        if stop == 0:
            new_words.append(word)
        if 'C_FIG' in word:
            stop = 0
        if 'C_TBL' in word:
            stop = 0        
        if '\n' in word:
            pointer = 1
        else:
            pointer = 0

    abstract_list[i] = ' '.join(new_words)
    abstract_list
print(abstract_list[4909])
# Out:
# The uses of bivalve molluscs in environmental biomonitoring have recently gained momentum due to their ability to indicate and concentrate human pathogenic microorganisms. In the context of the health crisis caused by the COVID-19 epidemic, the objective of this study was to determine if the SARS-CoV-2 ribonucleic acid genome can be detected in zebra mussels (Dreissena polymorpha) exposed to raw and treated urban wastewaters from two separate plants to support its interest as bioindicator of the SARS-CoV-2 genome contamination in water. The zebra mussels were exposed to treated wastewater through caging at the outlet of two plants located in France, as well as to raw wastewater at laboratory scale in controlled conditions. Within their digestive tissues, our results showed that SARS-CoV-2 genome was detected in zebra mussels, whether in raw and treated wastewaters. Moreover, the detection of the SARS-CoV-2 genome in such bivalve molluscans appeared even with low concentrations in raw wastewaters. This is the first detection of the SARS-CoV-2 genome in the tissues of a sentinel species exposed to raw and treated urban wastewaters. Despite the need for development for quantitative approaches, these results support the importance of such invertebrate organisms, especially zebra mussel, for the active surveillance of pathogenic microorganisms and their indicators in environmental waters.

# %%
first_words = set()
for i, abstract in enumerate(abstract_list):
    hits = []
    sentences = re.split('\n', abstract)
    for sent in sentences:
        try:
            first = sent.split()[0]
        except:
            first = ''
        hits.append(re.findall(r'\w*[A-Z]\w*[A-Z]\w*', first))
    #if hit:
    if sum([len(elem) for elem in hits]) > 0:
        for elem in hits:
            if len(elem) > 0:
                first_words.add(elem[0])

term_list = ['Statement',]
for word in first_words:
    present = 0
    for term in term_list:
        if term in word:
            present = 1
            break
    if present == 0:
        print(word)
# Out:
# MTT
# PI4KIII
# FusonAI
# RELN
# OntoFAST
# CDYL1
# PlaF
# AM
# OCI
# ToC
# BSD2
# HIV
# PoxtA
# TRIM25
# MFB
# PIWI
# KTD
# InformationThe
# iNKTs
# ZAP
# tRNAscan
# MCM
# PAM
# KRAS
# ZMIZ1
# HCDs
# STATEMENTLipids
# GGCT
# PSGL
# SAIGE
# MADS
# WNK463
# AQ
# SALARECON
# LOTUS
# CspA
# ADPr
# SARS
# FunctIonaL
# NMR
# ABC
# HEK293
# DsbA
# APOE
# EVs
# CSF
# PspA
# ASySD
# ParagraphAmong
# Pitx2ASE
# CBVF
# DWARF14
# ABCB1
# UP
# NEIL1
# TOC
# TMEM120A
# CICLOP
# LRFR
# MutS
# URLhttps
# 1RNA
# MiR
# miRNA
# OF
# eDNA
# PSMA
# STATEMENTDifferent
# IDH
# DeepFlu
# EM
# NetTIME
# BRAKER
# mRNA
# NF
# CDCP1
# ACE2
# MigVax
# EPEC
# MicroRNA
# BRIEF
# CellProfiler
# AIM
# UV
# FOXO
# POGZ
# ETV2
# CDK9
# RNF213
# DeRegNet
# DMSO
# FN
# TH
# MVPAlab
# GSDMB2
# ZGA
# ER
# GIV
# GIGANTEA
# LI
# AxonDeep
# SAR116
# InterARTIC
# DDA
# GABA
# PG9
# PARAGRAPHViruses
# SLP
# KMT2D
# RAS
# ONE
# LY
# VERNALIZATION
# OrientAGraph
# PKA
# PTEN
# EHP
# HLA
# CD33
# PavlopoulosLab
# TRAAK
# KEY
# RNF43
# BLENDS
# AMS
# tRNAs
# DNA
# RAD51
# SNARE
# REV
# MC
# HVEM
# CR
# RevGadgets
# NGLY1
# HPV
# TYPE
# TBE
# RMRP
# ATF4
# ZNF462
# Transition_Disorder_Prediction
# TORTE
# CUAnshcutz
# CT
# CNS
# TREM2
# AOM
# ORF3a
# BlurbER
# ATB0
# EDTA
# STATEMENTBy
# CHARGE
# TNBC
# PatAGE
# miCLIP2
# MRSE
# PyHDX
# PS2APP
# SHP2
# CPC
# NickJD
# STATEMENTDNAAF3
# EP300
# SwrA
# SLC9A6
# LRRC8A
# GFI1
# H2S
# ATL
# MatrixQCVis
# AAA
# CPM
# CNBP
# HAUSP
# DUX4
# GeneTonic
# NEMo
# NP
# HFOs
# MukBEF
# RAGE
# AGT
# HAT1
# NFIA
# ThruTracker
# CD4
# EEG
# GRASP55
# UniProt
# MCX
# PaReBrick
# DATA
# SHAPE
# TDFragMapper
# C_SCPCAPO_SCPLOWC_SCPLOWNatural
# AUTHOR
# US
# cfMeDIP
# COI
# BMP
# FGF
# N501Y
# F1Fo
# DECLARATIONS
# FusionAI
# SummaryNPMc
# ABSTRACTThe
# ABCA1
# ASE
# ATP13A2
# BULLET
# CIViC
# HOX
# SEEG
# TMPRSS2
# CCS
# COPD
# LncRNA
# MCA
# CEP78
# WHAT
# DeepRibo
# MT1
# YAP
# SIX1
# EXPERIMENTAL
# ISG15
# dCNBP
# hCDKL5
# SILVER
# LongStitch
# STUDY
# SOCS3
# PIEZO
# GWAS
# CD177
# ATF6
# SpFN
# FLAME
# ELMO1
# RingkasanMemahami
# GRAPHIC
# PTPRT
# ABIG1
# NPEPPS
# NmMetQ
# SCoPE2
# BioTIP
# FIB
# VIR
# CXCR6
# SETDB1
# MDM
# C_SCPCAPO_SCPLOWC_SCPLOWMembers
# FiberSim
# WS
# PAP1
# CrAss
# POU
# ACES
# PubMed
# BICEPS
# CRISPR
# CHCHD10
# KIM
# HBD3
# PKC
# RNases
# OsSRT1
# CAN
# HDnGAN
# FTY720
# THC
# DatumKB
# SUMO
# MERGE
# QSMxT
# SCOUR
# TSEBRA
# GCGR
# TACSTD2
# ATP
# cAMP
# TRPC5
# TissueGinder
# DeepImageJ
# GeneGrouper
# HKG
# COPII
# WGS
# RAG1
# CD24
# ID8
# RNAs
# RF
# expATXN2
# COBREXA
# ALK1
# DAGLa
# NanoSpring
# HIGHLIGHT
# PodoCount
# CFTR
# CAF
# STRipy
# ORAI1
# CRC
# fMRS
# eQTL
# CIC
# DIP
# MAGE
# CRISPRs
# IN
# KdpFABC
# GraphOmics
# ISF
# RAVs
# AMPK
# GTPases
# CaD23
# DRD2
# GRINA
# SentenceSex
# GUIdEStaR
# RNA
# SINEs
# GenomicSuperSignature
# CDK4
# EP400
# O_QD
# PERMANOVA
# BlurbSingle
# FoF1
# PRA
# COVID
# SW480
# GRAPHICAL
# NON
# TnCentral
# HIGHLIGHTS
# MMMVI
# HdeA
# mCRP
# statementOPC
# SARM1
# ProLung
# IL
# MiRNA
# CD70
# FAIRSCAPE
# CD8
# USP5
# FTSJ1
# NLoed
# CcoA
# DeepMP
# DeepMind
# sGuideMaker
# eIF5A
# HO_SCPLOWIGHLIGHTSC_SCPLOW
# PIK3CA
# HP1
# SignificanceHalf
# ProCanBio
# CRHs
# microRNAs
# DLEU2
# MSC
# XPCT
# mTORC2
# CRS
# MIC50
# GABAergic
# ParagraphEpisodic
# GC
# TRIB1
# TALPID3
# LncRNAs
# ROCK1
# BlurbThe
# CBMOS
# SGC5
# NOTCH1
# CTCF
# PACS
# HSV
# MicroRNAs
# ACM
# ATRX
# aeruginosaExoU
# NAM
# SignalP
# PDL1
# SWAN

# %%
data_biorxiv_curate = data_biorxiv.copy()
data_biorxiv_curate['abstract'] = abstract_list
data_biorxiv_curate.to_csv('processed/biorxiv_june_curate.csv', index=False)
